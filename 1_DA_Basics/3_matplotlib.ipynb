# %%
# !pip install datasets

# %%
import pandas as pd
from datasets import load_dataset

# %%
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_641/985178315.py in <cell line: 0>()
#       2 y = [1, 2, 3, 4]
#       3
# ----> 4 plt.plot(x, y)
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

plt.plot(x, y)

# %%
x = [1, 2, 3, 4]
y = [1, 2, 3, 4]

plt.plot(x, y)
plt.show()

# %%
import numpy as np

# %%
x = np.arange(0, 5, .1)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# ***Plotting***

# %%
df.job_posted_date.head()
# Out:
# 0   2023-06-16 13:44:15
# 1   2023-01-14 13:18:07
# 2   2023-10-10 13:14:55
# 3   2023-07-04 13:01:41
# 4   2023-08-07 14:29:36
# Name: job_posted_date, dtype: datetime64[ns]

# %%
plt.plot(df.job_posted_date, df.job_posted_date)

# %% [markdown]
# how many job postings are happening on particular date

# %%
date_counts = df.job_posted_date.value_counts()

# %%
type(date_counts)
# Out:
# pandas.core.series.Series

# %% [markdown]
# plot this date and count of **job**

# %%
plt.plot(date_counts.index, date_counts) #index for job posted date on x and value on y

# %%
#its not sorted therefore plot is looking like this

date_counts = date_counts.sort_index()

# %%
plt.plot(date_counts.index, date_counts)

# %%
date_counts
# Out:
# job_posted_date
# 2023-08-24 11:35:33    10
# 2023-01-01 23:37:09    10
# 2023-01-01 14:07:23    10
# 2023-11-09 09:02:12    10
# 2023-06-20 17:19:57    10
#                        ..
# 2023-06-08 07:43:38     1
# 2023-01-12 06:12:32     1
# 2023-10-16 06:01:53     1
# 2023-10-07 06:15:14     1
# 2023-06-07 06:18:29     1
# Name: count, Length: 607192, dtype: int64

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
#see monthly counts
monthly_counts = df.job_posted_month.value_counts()

monthly_counts = monthly_counts.sort_index()

monthly_counts
# Out:
# job_posted_month
# 1     91822
# 2     64578
# 3     64084
# 4     62919
# 5     52104
# 6     61572
# 7     63777
# 8     75162
# 9     62359
# 10    66611
# 11    64450
# 12    56303
# Name: count, dtype: int64

# %%
#plot month on x axis and count on y axis

plt.plot(monthly_counts.index, monthly_counts)

# %%
plt.plot(monthly_counts.index, monthly_counts.values)

# %%
pd.Series([10, 20, 30, 40, 50])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
series = pd.Series([10, 20, 30, 40, 50], index=['a', 'b', 'c', 'd', 'e'])

# %%
series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
series.values
# Out:
# array([10, 20, 30, 40, 50])

# %% [markdown]
# Bar Charts - counts of job **postings**

# %%
df.job_title_short.value_counts()  #count job titles  / gives series of count
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
job_counts = df.job_title_short.value_counts()

# %%
plt.plot(df.job_title_short.index, df.job_title_short.values)

# %%
plt.bar(job_counts.index, job_counts)
# Out:
# <BarContainer object of 10 artists>

# %%
job_counts = df.job_title_short.value_counts().head(3)

# %%
plt.bar(job_counts.index, job_counts)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Hori
