# %%
import pandas as pd

df = pd.read_excel(
    r"D:\customer_churn_and_retention_project\customer_churn.xlsx",
    sheet_name="customer_churn"
)

df.to_csv(
    r"D:\customer_churn_and_retention_project\customer_churn.csv",
    index=False
)

print("CSV created successfully!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_excel(
#       4     r"D:\customer_churn_and_retention_project\customer_churn.xlsx",
#       5     sheet_name="customer_churn"
#       6 )
#       8 df.to_csv(
#       9     r"D:\customer_churn_and_retention_project\customer_churn.csv",
#      10     index=False
#      11 )
#      13 print("CSV created successfully!")
#
# File c:\Users\Nikita Magar\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
# ...

# %%
import pandas as pd

excel_file = pd.ExcelFile(r"D:\customer_churn_and_retention_project\customer_churn.xlsx")

print(excel_file.sheet_names)
# Out:
# ['Sheet1', 'customer_churn_1M', 'KPI', 'Dashboard']

# %%
import pandas as pd

df = pd.read_excel(
    r"D:\customer_churn_and_retention_project\customer_churn.xlsx",
    sheet_name="customer_churn_1M"
)

df.to_csv(
    r"D:\customer_churn_and_retention_project\customer_churn.csv",
    index=False
)

print("CSV created successfully!")
# Out:
# CSV created successfully!

# %%
import pandas as pd

df = pd.read_csv(r"D:\customer_churn_and_retention_project\customer_churn.csv")

print(df.shape)
print(df.head())
# Out:
# (1000000, 37)
#       customer_id signup_date  age gender  annual_income    education  \
# 0  Cust0000003689  2024-05-18   41   Male        20000.0      College
# 1  Cust0000004347  2023-06-15   44   Male        20000.0      College
# 2  Cust0000012955  2024-10-27   58   Male        20000.0  High_School
# 3  Cust0000015109  2021-10-20   54   Male        20000.0     Bachelor
# 4  Cust0000020563  2021-12-12   46   Male        20000.0     Bachelor
#
#   marital_status  dependents  tenure  contract  ... late_payments  \
# 0        Married           0      34  One_Year  ...             0
# 1        Married           0      30  One_Year  ...             0
# 2        Married           0      25  One_Year  ...             0
# 3        Married           0      10  One_Year  ...             0
# 4        Married           0      22  One_Year  ...             0
#
#   avg_monthly_gb  days_since_last_interaction  credit_score  churn  \
# ...
