# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df['job_work_from_home'].value_counts()
# Out:
# job_work_from_home
# False    716189
# True      69552
# Name: count, dtype: int64

# %%
df['job_work_from_home'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['job_work_from_home'].value_counts().plot(kind='pie')
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='pie')
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_title_short'].value_counts().plot(kind='barh')
plt.title('Work from home status')
plt.ylabel("")
#plt.in()
plt.show()

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90)
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1f')  #autopct=auto percentage
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1.1f')  #autopct=auto percentage
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df['job_work_from_home'].value_counts().plot(kind='pie', startangle=90, autopct='%1.1f%%')  #autopct=auto percentage
plt.title('Work from home status')
plt.ylabel("")
plt.show()

# %%
df[['job_work_from_home', 'job_no_degree_mention', 'job_health_insurance']]
# Out:
#         job_work_from_home  job_no_degree_mention  job_health_insurance
# 0                    False                  False                 False
# 1                    False                  False                 False
# 2                    False                  False                 False
# 3                    False                   True                 False
# 4                    False                  False                 False
# ...                    ...                    ...                   ...
# 785736               False                  False                 False
# 785737               False                  False                 False
# 785738               False                  False                 False
# 785739               False                  False                 False
# 785740               False                  False                 False
#
# [785741 rows x 3 columns]

# %%
fig, ax = plt.subplots()

ax.pie(df['job_work_from_home'].value_counts())
plt.show()

# %%
dict_col = {
    'job_work_from_home' : 'work from home',
    'job_no_degree_mention' : 'job degree req', 
    'job_health_insurance' : 'health issuance offered'
}

for i, (col, title) in enumerate(dict_col.items()):   #enumerate - provides index
    print(i, col, title)
# Out:
# 0 job_work_from_home work from home
# 1 job_no_degree_mention job degree req
# 2 job_health_insurance health issuance offered

# %%
fig, ax = plt.subplots(1, 3)

dict_col = {
    'job_work_from_home' : 'work from home',
    'job_no_degree_mention' : 'job degree req', 
    'job_health_insurance' : 'health issuance offered'
}

for i, (col, title) in enumerate(dict_col.items()):   #enumerate - provides index
    print(i, col, title)

# %%
fig, ax = plt.subplots(1, 3)

dict_col = {
    'job_work_from_home' : 'work from home',
    'job_no_degree_mention' : 'job degree req', 
    'job_health_insurance' : 'health issuance offered'
}

for i, (col, title) in enumerate(dict_col.items()):   #enumerate - provides index
    ax[i].pie(df[col].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False', 'True'])
    ax[i].set_title(title)
