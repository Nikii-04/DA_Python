# %%
import pandas as pd
import matplotlib.pyplot as plt

from datasets import load_dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# pandas.df.sample
#
# return a random sample rows from dataframe

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 705072       Business Analyst
# 187922  Senior Data Scientist
# 519047       Business Analyst
# 58627            Data Analyst
# 479716       Business Analyst
# 462757   Senior Data Engineer
# 403396       Business Analyst
# 237441          Data Engineer
# 558442         Data Scientist
# 297081          Data Engineer
#
#                                                 job_title  \
# 705072                       Workforce Management Analyst
# 187922                                Senior Data science
# 519047              AI & Business Analyst (Medior/Senior)
# 58627   Production Operations Database Analyst/Adminis...
# 479716                                   Business Analyst
# 462757                               Senior Data Engineer
# 403396                            Junior Business Analyst
# 237441                                  Sr. Data Engineer
# 558442                                     Data Scientist
# ...

# %%
df.sample(10, random_state=42)   #random_state=42 → fixes the randomness so you get the same 10 rows every time you run the code
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
# 183426           Data Analyst
# 287790           Data Analyst
# 541983           Data Analyst
# 416896         Data Scientist
# 780907          Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
# 183426                                       Data Analyst
# 287790                                       Data Analyst
# 541983                   Data Analyst, Cloud Systems Jobs
# 416896             Alternant Actuariat & Data Science H/F
# ...

# %%
df.sample(frac=.01)  #1% of the df
# Out:
#             job_title_short  \
# 628419  Senior Data Analyst
# 624241     Business Analyst
# 529307        Data Engineer
# 546810         Data Analyst
# 532846  Senior Data Analyst
# ...                     ...
# 101141         Data Analyst
# 781889       Cloud Engineer
# 18245   Senior Data Analyst
# 324128       Data Scientist
# 568581        Data Engineer
#
#                                                 job_title  \
# 628419              100% Fully Remote Senior Data Analyst
# 624241                                Production Engineer
# 529307                                  Sr. Data Engineer
# 546810                           Entry Level Data Analyst
# 532846  Senior Big Data Analyst / PM. Job in Wilmingto...
# ...                                                   ...
# 101141                                       Data Analyst
# 781889                                     Civil Engineer
# 18245                Senior Data Analyst - Firm Analytics
# ...

# %% [markdown]
# copy-  make a copy of this obj's indices and data

# %%
#df is also updated as df_filled and df_unique when we update any col in df_filled ex- df_filled['job_title'] = df_filled

#df_filled = df  both will be same when updated
#for that we need copy

# %%
df_new = df

# %%
id(df)
# Out:
# 1479559914432

# %%
id(df_new)
# Out:
# 1479559914432

# %%
id(df) == id(df_new)
# Out:
# True

# %%
df_original = df.copy()

# %%
print(id(df), id(df_original), id(df) == id(df_original))
# Out:
# 1479559914432 1479599586288 False

# %% [markdown]
# fill nan with median in salary_year_avg col and display 5 rows and see df

# %%
median_sal = df_original['salary_year_avg'].median()
df_original['salary_year_avg'] = df_original['salary_year_avg'].fillna(median_sal)
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64
