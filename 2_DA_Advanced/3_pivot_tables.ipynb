# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from datasets import load_dataset

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# Counts of Job titles

# %%
df.pivot_table(index='job_title_short', aggfunc='size')
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %%
df.groupby('job_title_short').size()
# Out:
# job_title_short
# Business Analyst              49063
# Cloud Engineer                12331
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Machine Learning Engineer     14080
# Senior Data Analyst           29216
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Software Engineer             44929
# dtype: int64

# %% [markdown]
# Median sal by job

# %%
df.pivot_table(index='job_title_short', values='salary_year_avg', aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                   85000.0
# Cloud Engineer                     90000.0
# Data Analyst                       90000.0
# Data Engineer                     125000.0
# Data Scientist                    127500.0
# Machine Learning Engineer         106415.0
# Senior Data Analyst               111175.0
# Senior Data Engineer              147500.0
# Senior Data Scientist             155500.0
# Software Engineer                  99150.0

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.pivot_table(index='job_title_short', values='salary_year_avg', columns='job_country', aggfunc='median')
# Out:
# job_country                  Albania  Algeria  Argentina   Armenia  Australia  \
# job_title_short
# Business Analyst                 NaN      NaN   71100.00       NaN    70000.0
# Cloud Engineer                   NaN      NaN  197500.00       NaN   110000.0
# Data Analyst                49950.00  44100.0   92771.75  100500.0   109500.0
# Data Engineer                    NaN  45000.0   96773.00   48750.0   106712.5
# Data Scientist              69981.25      NaN   71000.00       NaN   139216.0
# Machine Learning Engineer        NaN      NaN  101029.00   87021.0   101029.0
# Senior Data Analyst              NaN      NaN        NaN       NaN    50640.0
# Senior Data Engineer             NaN      NaN  147500.00       NaN   147500.0
# Senior Data Scientist      157500.00      NaN        NaN       NaN   157500.0
# Software Engineer                NaN      NaN  174500.00       NaN   118350.0
#
# job_country                  Austria  Azerbaijan   Bahamas  Bangladesh  \
# job_title_short
# ...

# %% [markdown]
# Bar graph - median sal by country and job title

# %%
top_countries = df['job_country'].value_counts().head(5).index
top_countries
# Out:
# Index(['United States', 'India', 'United Kingdom', 'France', 'Germany'], dtype='object', name='job_country')

# %%
df_job_country_sal = df.pivot_table(     #index used as groupby
    index='job_country', 
    values='salary_year_avg', 
    columns='job_title_short', 
    aggfunc='median')

# %%
df_job_country_sal = df_job_country_sal.loc[top_countries]
df_job_country_sal
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# United States             90000.0        116100.0       90000.0
# India                     64800.0             NaN      100500.0
# United Kingdom            56700.0             NaN       87750.0
# France                    89100.0        105968.0       69175.0
# Germany                   89100.0         89100.0      103750.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# United States         125000.0        130000.0                   150000.0
# India                 147500.0        114008.0                    79200.0
# United Kingdom        110000.0        105300.0                   149653.0
# France                 98301.5         88128.0                    80850.0
# Germany               147500.0        131560.0                    89100.0
#
# job_title_short  Senior Data Analyst  Senior Data Engineer  \
# job_country
# ...

# %%
df_job_country_sal.loc[[2, 3, 4]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_job_country_sal.loc[[2, 3, 4]]
#
# File c:\Users\Nikita Magar\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Nikita Magar\anaconda3\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# ...

# %%
job_titles = ['Data Analyst', 'Data Engineer' , 'Data Scientist']

# %%
df_job_country_sal = df_job_country_sal[job_titles]
df_job_country_sal
# Out:
# job_title_short  Data Analyst  Data Engineer  Data Scientist
# job_country
# Albania              49950.00            NaN        69981.25
# Algeria              44100.00        45000.0             NaN
# Argentina            92771.75        96773.0        71000.00
# Armenia             100500.00        48750.0             NaN
# Australia           109500.00       106712.5       139216.00
# ...                       ...            ...             ...
# Uruguay             100500.00            NaN             NaN
# Uzbekistan                NaN            NaN        30750.00
# Vietnam              75550.00        96773.0        70000.00
# Zambia                    NaN            NaN        90670.00
# Zimbabwe             63000.00            NaN        69085.00
#
# [108 rows x 3 columns]

# %%
df_job_country_sal = df_job_country_sal[job_titles].head(10)

# %%
df_job_country_sal.plot(kind='bar')
# Out:
# <Axes: xlabel='job_country'>

# %%
df_job_country_sal.plot(kind='bar')
plt.xlabel('')
plt.ylabel('median salary')
plt.title('Median sal by job title and country')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df_job_country_sal.plot(kind='barh')
plt.xlabel('')
plt.ylabel('median salary')
plt.title('Median sal by job title and country')
plt.xticks(rotation=45, ha='right')
plt.show()
